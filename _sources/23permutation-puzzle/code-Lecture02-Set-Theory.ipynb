# %% [markdown]
# This is an ipython (jupyter) worksheet with code from the lecture notes for the course
# **Permutation Puzzles: A Mathematical Perspective**, by Jamie Mulholland
#
# Coures webpage: http://www.sfu.ca/~jtmulhol/math302 <br />
# Course notes booklet: http://www.sfu.ca/~jtmulhol/math302/notes/302notes.pdf

# %% [markdown]
# # Lecture 2: Set Theory
#
# ## 2.4 Examples Using Sage Math

# %%
S1=Set([1,2,3,4,5]);
S2=Set([3,4,5,6,7]);
print S1,S2
# Out:
# {1, 2, 3, 4, 5} {3, 4, 5, 6, 7}

# %%
S1.cardinality()
# Out:
# 5

# %%
S1.union(S2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
S1.intersection(S2)
# Out:
# {3, 4, 5}

# %%
S1.difference(S2)
# Out:
# {1, 2}

# %%
S2.difference(S1)
# Out:
# {6, 7}

# %%
cartesian_product([S1, S2])
# Out:
# The Cartesian product of ({1, 2, 3, 4, 5}, {3, 4, 5, 6, 7})

# %%
for i in cartesian_product([S1,S2]):
    print i
# Out:
# (1, 3)
# (1, 4)
# (1, 5)
# (1, 6)
# (1, 7)
# (2, 3)
# (2, 4)
# (2, 5)
# (2, 6)
# (2, 7)
# (3, 3)
# (3, 4)
# (3, 5)
# (3, 6)
# (3, 7)
# (4, 3)
# (4, 4)
# (4, 5)
# (4, 6)
# (4, 7)
# (5, 3)
# (5, 4)
# (5, 5)
# (5, 6)
# (5, 7)

# %%
2 in S1
# Out:
# True

# %%
1 in S2
# Out:
# False
